# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()
# Out:
# True

# %%
# get the instance of the genrative model
llm  = ChatGoogleGenerativeAI(model= "gemma-4-31b-it")

response = llm.invoke("How many moons does jupiter have?")
print(response.text)
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# Jupiter has **95 recognized moons**.
#
# This number can change as astronomers discover new, smaller moons using more powerful telescopes. The most famous of these are the four largest, known as the **Galilean moons**: Io, Europa, Ganymede, and Callisto.

# %%
# lets give system prompt to the genAI which indicates in what format we want the answer
response = llm.invoke([
    ["system"," You are a helpful assistant that answers in single line"],
    ["human","How many moons does Jupiter have?"],
])

print(response.text)
# Out:
# Jupiter has 95 moons.

# %%
# lets set the temparature value which indicates how creative the llm should be
prompt = "Write a single tagline for quirky coffee shop. Only output the tagline, nothing else"

llm = ChatGoogleGenerativeAI(model = "gemini-3.7-flash",temperature = 0)
response = llm.invoke(prompt)
print(response.text)
# Out:
# Seriously good coffee for delightfully strange people.

# %%
# lets change the temperature to 1 and see how creatively the model responds
llm = ChatGoogleGenerativeAI(model = "gemini-3.7-flash",temperature = 1)
response = llm.invoke(prompt)
print(response.text)
# Out:
# Strange brews for peculiar people.

# %%
from langchain_groq import ChatGroq

# %%
# Calling Groq models
llm = ChatGroq(model = "qwen/qwen3.6-27b", reasoning_format="parsed")

messages = [
    (
        'system',
        "You are helpful assistant that gives a short answer to a question",
    ),
    (
        "human",
        "How many moons does Jupiter have?"
    ),
]

ai_msg = llm.invoke(messages)
print(ai_msg.content)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[16], line 15
#      11         "How many moons does Jupiter have?"
#      12     ),
#      13 ]
#      14
# ---> 15 ai_msg = llm.invoke(messages)
#      16 print(ai_msg.content)
#
# File c:\Projects\udemy\aws-courses\AgenticAI\AgenticAI_Langchain\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:488, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     474 @override
#     475 def invoke(
#     476     self,
#    (...)    481     **kwargs: Any,
#     482 ) -> AIMessage:
#     483     config = ensure_config(config)
#     484     return cast(
#     485         "AIMessage",
#     486         cast(
#     487             "ChatGeneration",
# --> 488             self.generate_prompt(
#     489                 [self._convert_input(input)],
#     490                 stop=stop,
# ...
